# %%
ta = list("TechAcademy")

# %%
print(ta.count("T"))
print(ta.count("e"))
print(ta.count("b"))
# Out:
# 1
# 2
# 0

# %%
char = "e" # char: **charater**から
char_count = ta.count(char)
if char_count: # `if char_count != 0:`と同等
    print(f"文字「{char}」はリスト{ta}に{char_count}回含まれます。")
else:
    print(f"文字「{char}」はリスト{ta}に含まれません。")

char = "x"
char_count = ta.count(char)
if char_count:
    print(f"文字「{char}」はリスト{ta}に{char_count}回含まれます。")
else:
    print(f"文字「{char}」はリスト{ta}に含まれません。")
# Out:
# 文字「e」はリスト['T', 'e', 'c', 'h', 'A', 'c', 'a', 'd', 'e', 'm', 'y']に2回含まれます。
# 文字「x」はリスト['T', 'e', 'c', 'h', 'A', 'c', 'a', 'd', 'e', 'm', 'y']に含まれません。

# %%
char = "A" # char: **charater**から
char_count = ta.count(char)
if char_count: # `if char_count != 0:`と同等
    print(f"文字「{char}」はリスト{ta}に{char_count}回含まれます。")
else:
    print(f"文字「{char}」はリスト{ta}に含まれません。")
# Out:
# 文字「A」はリスト['T', 'e', 'c', 'h', 'A', 'c', 'a', 'd', 'e', 'm', 'y']に1回含まれます。

# %%
ta = list("TechAcademy")
print(ta.index("T"))
print(ta.index("e"))
# Out:
# 0
# 1

# %%
char = "b"
if char in ta:
    print(ta.index(char))
else:
    print(None)
# Out:
# None

# %%
nums = [4, 7, 1, 6, 3, 2, 5]
nums
# Out:
# [4, 7, 1, 6, 3, 2, 5]

# %%
nums.sort()
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums.reverse()
nums
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
fruits = ["orange", "banana", "peach", "apple", "grape"]
fruits
# Out:
# ['orange', 'banana', 'peach', 'apple', 'grape']

# %%
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange', 'peach']

# %%
fruits.reverse()
fruits
# Out:
# ['peach', 'orange', 'grape', 'banana', 'apple']

# %%
nums = [4, 7, 1, 6, 3, 2, 5]

# %%
nums2 = sorted(nums)
print(nums)
print(nums2)
# Out:
# [4, 7, 1, 6, 3, 2, 5]
# [1, 2, 3, 4, 5, 6, 7]

# %%
nums3= sorted(nums, reverse=True)
print(nums)
print(nums3)
# Out:
# [4, 7, 1, 6, 3, 2, 5]
# [7, 6, 5, 4, 3, 2, 1]

# %%
nums = []
for i in range(5, 11): # 5から11-1までの整数
    nums.append(i * 3.14) # iを3.14倍したもの

nums
# Out:
# [15.700000000000001, 18.84, 21.98, 25.12, 28.26, 31.400000000000002]

# %%
nums_oneline =[i * 3.14 for i in range (5, 11) ]
nums_oneline
# Out:
# [15.700000000000001, 18.84, 21.98, 25.12, 28.26, 31.400000000000002]

# %%
math_numbers = [3.1415926535897, 2.71828182846, 1.618033988749894848204]

# %%
# 新しいリストを定義する
math_numers_new = []
for num in math_numbers:
    math_numers_new.append(round(num, 3)) # 四捨五入した結果を新しいリストに格納する
math_numbers = math_numers_new # 元のリストを新しいリストで上書きする
math_numbers
# Out:
# [3.142, 2.718, 1.618]

# %%
math_numbers = [round(num, 3) for num in math_numbers]
math_numbers
# Out:
# [3.142, 2.718, 1.618]

# %%
num4 = [i for i in range(11) if i % 2 == 0]
num4
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
num4 = [i for i in range (11) if i 2%==0]
# Out:
#   Cell In[23], line 1
#     num4 = [i for i in range (11) if i 2%==0]
#                                        ^
# SyntaxError: invalid syntax

# %%
num4 = [i for i in range(11) if i % 2 == 0]
num4
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
num4 = [i for i in range(11) if i % 2 == 0 and i % 3 == 0]
num4
# Out:
# [0, 6]

# %%
num4 = ["even" if i % 2 == 0 else "odd" for i in range(11)]
num4
# Out:
# ['even',
#  'odd',
#  'even',
#  'odd',
#  'even',
#  'odd',
#  'even',
#  'odd',
#  'even',
#  'odd',
#  'even']

# %%
num5 = ["low" if i < 3 else "mid" if i < 8 else "hi" for i in range(11)]
num5
# Out:
# ['low', 'low', 'low', 'mid', 'mid', 'mid', 'mid', 'mid', 'hi', 'hi', 'hi']

# %%
def number_to_degree(i):
    if i < 3:
        return "low"
    else:
        if i < 8:
            return "mid"
        else:
            return "hi"

num5_alt = [number_to_degree(i) for i in range(11)]
num5_alt
# Out:
# ['low', 'low', 'low', 'mid', 'mid', 'mid', 'mid', 'mid', 'hi', 'hi', 'hi']

# %%
num7 = ["Fizz" if i % 3 == 0 else "Buzz" if i % 5 ==0 for i in range(31)]
nym7
# Out:
#   Cell In[33], line 1
#     num7 = ["Fizz" if i % 3 == 0 else "Buzz" if i % 5 ==0 for i in range(31)]
#                                       ^
# SyntaxError: expected 'else' after 'if' expression

# %%
def kadai_num(i):
    if i % 15 ==0:
        return "FizzBuzz"
    else:
        if i % 3 ==0:
            return"Fizz"
        else:
            if i % 5 ==0:
                return"Buzz"
            else:
                return(f'{i}') 
                  
num6 = [kadai_num(i) for i in range(31)]
num6
# Out:
# ['FizzBuzz',
#  '1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14',
#  'FizzBuzz',
#  '16',
#  '17',
#  'Fizz',
#  '19',
#  'Buzz',
#  'Fizz',
#  '22',
#  '23',
#  'Fizz',
#  'Buzz',
#  '26',
#  'Fizz',
#  '28',
#  '29',
#  'FizzBuzz']

# %%
num6 = [
    "FizzBuzz" if i % 15 == 0 else
    "Fizz" if i % 3 == 0 else
    "Buzz" if i % 5 == 0 else
    str(i)
    for i in range(31)
]
num6
# Out:
# ['FizzBuzz',
#  '1',
#  '2',
#  'Fizz',
#  '4',
#  'Buzz',
#  'Fizz',
#  '7',
#  '8',
#  'Fizz',
#  'Buzz',
#  '11',
#  'Fizz',
#  '13',
#  '14',
#  'FizzBuzz',
#  '16',
#  '17',
#  'Fizz',
#  '19',
#  'Buzz',
#  'Fizz',
#  '22',
#  '23',
#  'Fizz',
#  'Buzz',
#  '26',
#  'Fizz',
#  '28',
#  '29',
#  'FizzBuzz']

# %%
num7 = ["FizzBuzz" if i % 15 ==0 else "Fizz" if i % 3 ==0 else "Buzz" if i % 5 ==0 else f'{i}' for i in range(31)]
num7
# Out:
#   Cell In[57], line 1
#     num7 = ["FizzBuzz" if i % 15 ==0 else "Fizz" if i % 3 ==0 else "Buzz" if i % 5 ==0 else f'{i}' for i range(31)]
#                                                                                                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
num6 = ["FizzBuzz" if i % 15 == 0 else "Fizz" if i % 3 == 0 else "Buzz" if i % 5 == 0 else str(i) for i in range(1,101)]
print(num6)
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz', '16', '17', 'Fizz', '19', 'Buzz', 'Fizz', '22', '23', 'Fizz', 'Buzz', '26', 'Fizz', '28', '29', 'FizzBuzz', '31', '32', 'Fizz', '34', 'Buzz', 'Fizz', '37', '38', 'Fizz', 'Buzz', '41', 'Fizz', '43', '44', 'FizzBuzz', '46', '47', 'Fizz', '49', 'Buzz', 'Fizz', '52', '53', 'Fizz', 'Buzz', '56', 'Fizz', '58', '59', 'FizzBuzz', '61', '62', 'Fizz', '64', 'Buzz', 'Fizz', '67', '68', 'Fizz', 'Buzz', '71', 'Fizz', '73', '74', 'FizzBuzz', '76', '77', 'Fizz', '79', 'Buzz', 'Fizz', '82', '83', 'Fizz', 'Buzz', '86', 'Fizz', '88', '89', 'FizzBuzz', '91', '92', 'Fizz', '94', 'Buzz', 'Fizz', '97', '98', 'Fizz', 'Buzz']
