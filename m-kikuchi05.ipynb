# %%
fruits = []
fruits.append("apple")
fruits.append("banana")
fruits.append("orange")
fruits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 fruits.append("banana")
#       4 fruits.append("orange")
# ----> 5 fruit
#
# NameError: name 'fruit' is not defined
