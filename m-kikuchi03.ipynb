# %%
a = "Today is a sunny day."
a.replace("sunny", "rainy")
# Out:
# 'Today is a rainy day.'

# %%
a = "Today is a sunny day."
a.replace("sunny", "rainy")
a
# Out:
# 'Today is a sunny day.'

# %%
a = "Today is a sunny day."
a = a.replace("sunny", "rainy")
a
# Out:
# 'Today is a rainy day.'

# %%
a = "Tech Academy"
a
# Out:
# 'Tech Academy'

# %%
a.lower()
# Out:
# 'tech academy'

# %%
a.upper()
# Out:
# 'TECH ACADEMY'

# %%
a = "Tech Academy"
a = a.lower()
a
# Out:
# 'tech academy'

# %%
a = "Tech Academy"
a = a.upper()
a
# Out:
# 'TECH ACADEMY'

# %%
a.count("e")
# Out:
# 0

# %%
a.count("E")
# Out:
# 2

# %%
a = "      Tech Academy         "
a = a.strip()
a
# Out:
# 'Tech Academy'

# %%
a = """
ゥ

"""
a = a.strip()
a
# Out:
# 'ゥ'

# %%
str1 = "信号の色は{}と{}と{}"
str1 = str1.format("赤", "青", "黄色")
str1
# Out:
# '信号の色は赤と青と黄色'

# %%
station1 = "東京"
station2 = "新橋"
price = 140
str1 = f"{station1}から{station2}までの運賃は{price}円です。"
str1
# Out:
# '東京から新橋までの運賃は140円です。'

# %%
str1 = "{}から{}までの運賃は{}円です。"
str1 = str1.format("東京","新橋","140")
str1
# Out:
# '東京から新橋までの運賃は140円です。'

# %%
price = 2000
print(f"税込価格で{price}円です。")
# Out:
# 税込価格で2000円です。

# %%
price = 2000
print(f"税込価格で{price:,}円です。")
# Out:
# 税込価格で2,000円です。

# %%
price = 2000
print(f"税込価格で{price:.1f}円です。")
# Out:
# 税込価格で2000.0円です。
