# %%
score = int(input("点数を入力してください: "))

if score >= 60:
    print("合格です")

print("処理を終了します")
# Out:
# 合格です
# 処理を終了します

# %%
def exam(score):
    if score  >= 60:
        print("合格です")
        print("おめでとうございます！")
    print("処理を終了いたします")

# %%
exam(80)
# Out:
# 合格です
# おめでとうございます！
# 処理を終了いたします

# %%
exam(40)
# Out:
# 処理を終了いたします

# %%
age = int(input("年齢を入力してください: "))

if (age >= 18) and (age <= 65):
    print("どうぞお乗りください")

print("処理を終了します")
# Out:
# どうぞお乗りください
# 処理を終了します

# %%
age = int(input("年齢を入力してください："))
if age >= 18:
    if age <= 65:
        print("どうぞお乗りください")

print("処理を終了します")
# Out:
# 処理を終了します

# %%
score = int(input("点数を入力してください: "))
if score >= 60:
    print("合格です")
    print("おめでとうございます！")
else:
    print("不合格です")
    print("もっと頑張りましょう")

print("処理を終了します。")
# Out:
# 不合格です
# もっと頑張りましょう
# 処理を終了します。

# %%
price = int(input("税抜き価格を入力してください: "))
print(f"税抜き価格を入力してください:{price} ")
including_tax = round(price * 1.1)

if including_tax >= 2000:
    print("送料は無料です")
    print("送料込みの価格は", including_tax, "円です。")
else:
    print("送料として350円かかります")
    print("送料込みの価格は",including_tax + 350, "円です。")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(price = int(input("税抜き価格を入力してください: ")))
#       2 including_tax = round(price * 1.1)
#       4 if including_tax >= 2000:
#
# TypeError: 'price' is an invalid keyword argument for print()
