# %%
words_list =[]

alpha = dict.fromkeys(list("abcdefghijklmnopqrstuvwxyz"),0)

while True:
    words_input = input("英単語を入力してください： ")
    print(f"英単語を入力してください: {words_input} ")
    if words_input =="":
        break
    words_list.append(words_input) 
words_list.sort()
  
print(words_list)

for word in words_list:
    print("今のword:", word)
    for letter in word:
        print("  今のletter:", letter)
        if letter in alpha:
            alpha[letter]+=1

for k, v in alpha.items():
    if v >= 1:
        print(f"{k}が{v}個ありました")
# Out:
# 英単語を入力してください: table
# 英単語を入力してください: door
# 英単語を入力してください: chair
# 英単語を入力してください:
# ['chair', 'door', 'table']
# 今のword: chair
#   今のletter: c
#   今のletter: h
#   今のletter: a
#   今のletter: i
#   今のletter: r
# 今のword: door
#   今のletter: d
#   今のletter: o
#   今のletter: o
#   今のletter: r
# 今のword: table
#   今のletter: t
#   今のletter: a
#   今のletter: b
#   今のletter: l
#   今のletter: e
# aが2個ありました
# bが1個ありました
# cが1個ありました
# dが1個ありました
# eが1個ありました
# hが1個ありました
# iが1個ありました
# lが1個ありました
# oが2個ありました
# rが2個ありました
# tが1個ありました

# %%
mylist = []
alphabet = dict.fromkeys("\
abcdefghijklmnopqrstuvwxyz", 0)

while True:
    word = input('英単語を入力してください')
    if word == '':
        break
    mylist.append(word)
mylist.sort()
print(mylist)

for w in mylist:
    for c in w:
        try:
            alphabet[c] += 1
        except KeyError:
            pass

for k, v in alphabet.items():
    print(f'{k}が{v}個ありました')
# Out:
# ['apple ', 'banana', 'melon', 'orange']
# aが5個ありました
# bが1個ありました
# cが0個ありました
# dが0個ありました
# eが3個ありました
# fが0個ありました
# gが1個ありました
# hが0個ありました
# iが0個ありました
# jが0個ありました
# kが0個ありました
# lが2個ありました
# mが1個ありました
# nが4個ありました
# oが2個ありました
# pが2個ありました
# qが0個ありました
# rが1個ありました
# sが0個ありました
# tが0個ありました
# uが0個ありました
# vが0個ありました
# wが0個ありました
# xが0個ありました
# yが0個ありました
# zが0個ありました

# %%
numbers = [3, 7, 11]
print(numbers[0])
print(numbers[1])
print(numbers[2])
# Out:
# 3
# 7
# 11

# %%
numbers = [1, 2, 3, 4]
r=[]
for i in numbers:
    r.append(i*2)
print(r)
# Out:
# [2, 4, 6, 8]

# %%
word = "apple"
for w in word:
    print(w)
# Out:
# a
# p
# p
# l
# e

# %%
word = "banana"
for x in word:
    if (x == "a") or (x =="e") or (x =="i") or (x =="o") or (x =="u"):
        print(i)
# Out:
# a
# a
# a

# %%
l = []
for y in range(1, 11):
    if y % 2 == 0:
        l.append(y)

print(l)
# Out:
# [2, 4, 6, 8, 10]

# %%
words = ["cat", "dog"]
for w in words:
    for l in w:
        print(l)
# Out:
# c
# a
# t
# d
# o
# g

# %%
multi_l=[]
for a in range(1,10):
    for b in range(1,10):
        print(f"{a} x {b}={a*b}")
# Out:
# 1 x 1=1
# 1 x 2=2
# 1 x 3=3
# 1 x 4=4
# 1 x 5=5
# 1 x 6=6
# 1 x 7=7
# 1 x 8=8
# 1 x 9=9
# 2 x 1=2
# 2 x 2=4
# 2 x 3=6
# 2 x 4=8
# 2 x 5=10
# 2 x 6=12
# 2 x 7=14
# 2 x 8=16
# 2 x 9=18
# 3 x 1=3
# 3 x 2=6
# 3 x 3=9
# 3 x 4=12
# 3 x 5=15
# 3 x 6=18
# 3 x 7=21
# 3 x 8=24
# 3 x 9=27
# 4 x 1=4
# 4 x 2=8
# 4 x 3=12
# 4 x 4=16
# 4 x 5=20
# 4 x 6=24
# 4 x 7=28
# 4 x 8=32
# 4 x 9=36
# 5 x 1=5
# 5 x 2=10
# 5 x 3=15
# 5 x 4=20
# 5 x 5=25
# 5 x 6=30
# 5 x 7=35
# 5 x 8=40
# 5 x 9=45
# 6 x 1=6
# 6 x 2=12
# 6 x 3=18
# 6 x 4=24
# 6 x 5=30
# 6 x 6=36
# 6 x 7=42
# 6 x 8=48
# 6 x 9=54
# 7 x 1=7
# 7 x 2=14
# 7 x 3=21
# 7 x 4=28
# 7 x 5=35
# 7 x 6=42
# 7 x 7=49
# 7 x 8=56
# 7 x 9=63
# 8 x 1=8
# 8 x 2=16
# 8 x 3=24
# 8 x 4=32
# 8 x 5=40
# 8 x 6=48
# 8 x 7=56
# 8 x 8=64
# 8 x 9=72
# 9 x 1=9
# 9 x 2=18
# 9 x 3=27
# 9 x 4=36
# 9 x 5=45
# 9 x 6=54
# 9 x 7=63
# 9 x 8=72
# 9 x 9=81
